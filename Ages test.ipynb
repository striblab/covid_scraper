# %%
import os
import altair as alt
import pandas as pd
from django_pandas.io import read_frame
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
qs = StatewideAgeDate.objects.all()

# %%
df = read_frame(qs)
df['scrape_date'] = pd.to_datetime(df['scrape_date'])
df
# Out:
#     id scrape_date        age_group  cases_pct  deaths_pct  \
# 0   19  2020-05-03        0-5 years          1           0
# 1   20  2020-05-03       6-19 years          3           0
# 2   21  2020-05-03      20-29 years         16           0
# 3   22  2020-05-03      30-39 years         18          -1
# 4   23  2020-05-03      40-49 years         15           1
# ..  ..         ...              ...        ...         ...
# 94  27  2020-05-03  Unknown/missing         -1           0
# 95  72  2020-05-08  Unknown/missing         -1           0
# 96  93  2020-05-11       6-19 years          5           0
# 97  95  2020-05-11      30-39 years         20          -1
# 98  97  2020-05-11      50-59 years         16           5
#
#                         last_update
# 0  2020-05-04 04:04:04.463851+00:00
# 1  2020-05-04 04:04:04.566539+00:00
# 2  2020-05-04 04:04:04.669038+00:00
# 3  2020-05-04 04:04:04.771680+00:00
# 4  2020-05-04 04:04:04.874296+00:00
# ..                              ...
# 94 2020-05-11 20:51:33.561982+00:00
# 95 2020-05-11 20:51:33.665729+00:00
# 96 2020-05-11 19:29:50.108429+00:00
# 97 2020-05-11 19:29:50.252922+00:00
# 98 2020-05-11 19:29:50.395530+00:00
#
# [99 rows x 6 columns]

# %%
alt.Chart(df).mark_line().encode(
    x='scrape_date:T',
    y='deaths_pct',
    color='age_group',
#     strokeDash='age_group',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_line().encode(
    x='scrape_date:T',
    y='cases_pct',
    color='age_group',
#     strokeDash='age_group',
)
# Out:
# alt.Chart(...)
